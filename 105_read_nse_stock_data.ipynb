# %%
develop read data method
windowing technique for moving average
moving windows for different statistics
getting different statistics on moving window

# %% [markdown]
# ### Read historical and real time data from NSE

# %% [markdown]
# [NSE](https://nsepy.xyz/)

# %%
# ! pip install nsepy

# %%
from datetime import date
from nsepy import get_history as gh
from nsepy import get_history
import pandas as pd

# %%
data = get_history(symbol="SBIN", start=date(2015,1,1), end=date(2015,1,31))
data[['Close']].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
data.head()
# Out:
#            Symbol Series  Prev Close    Open    High     Low   Last   Close  \
# Date
# 2015-01-01   SBIN     EQ      311.85  312.45  315.00  310.70  314.0  314.00
# 2015-01-02   SBIN     EQ      314.00  314.35  318.30  314.35  315.6  315.25
# 2015-01-05   SBIN     EQ      315.25  316.25  316.80  312.10  312.8  312.75
# 2015-01-06   SBIN     EQ      312.75  310.00  311.10  298.70  299.9  299.90
# 2015-01-07   SBIN     EQ      299.90  300.00  302.55  295.15  301.4  300.15
#
#               VWAP    Volume      Turnover  Trades  Deliverable Volume  \
# Date
# 2015-01-01  313.67   6138488  1.925489e+14   58688             1877677
# 2015-01-02  316.80   9935094  3.147389e+14   79553             4221685
# 2015-01-05  313.84   9136716  2.867432e+14   88236             3845173
# 2015-01-06  305.14  15329257  4.677601e+14  169268             7424847
# 2015-01-07  299.95  15046745  4.513243e+14  147185             5631400
#
#             %Deliverble
# Date
# 2015-01-01       0.3059
# ...

# %%
start_date = date(2019, 1 , 7) 
end_date = date(2019, 5, 15)

# %%
start_date
# Out:
# datetime.date(2019, 1, 7)

# %%
df = pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
growth_stocks = ['APCL', 'BALRAMCHIN', 'PAGEIND', 'DECCANCE', 'KALPATPOWR', 'SAGCEM', 'LTI', 'BHARATRAS', 'NMDC']

# %%
growth_stocks
# Out:
# ['APCL',
#  'BALRAMCHIN',
#  'PAGEIND',
#  'DECCANCE',
#  'KALPATPOWR',
#  'SAGCEM',
#  'LTI',
#  'BHARATRAS',
#  'NMDC']

# %%
i = 0

# %%
print(i)
# Out:
# 0

# %%
gh(symbol=growth_stocks[i],start=start_date, end=end_date)
# Out:
#            Symbol Series  Prev Close    Open    High     Low    Last   Close  \
# Date
# 2019-01-07   APCL     EQ      129.55  129.00  131.50  126.00  126.15  126.25
# 2019-01-08   APCL     EQ      126.25  125.90  127.00  125.90  126.35  126.85
# 2019-01-09   APCL     EQ      126.85  134.00  134.00  126.15  126.15  126.15
# 2019-01-10   APCL     EQ      126.15  129.35  132.30  129.35  129.75  129.80
# 2019-01-11   APCL     EQ      129.80  133.35  133.40  126.15  127.00  128.75
# ...           ...    ...         ...     ...     ...     ...     ...     ...
# 2019-05-09   APCL     EQ      128.40  129.90  138.45  126.55  131.25  134.35
# 2019-05-10   APCL     EQ      134.35  131.65  134.55  131.65  134.00  133.25
# 2019-05-13   APCL     EQ      133.25  132.00  132.00  123.00  131.00  123.90
# 2019-05-14   APCL     EQ      123.90  125.80  133.00  122.25  133.00  131.40
# 2019-05-15   APCL     EQ      131.40  128.90  145.90  127.25  139.00  142.95
#
# ...

# %%
growth_stocks
# Out:
# ['APCL',
#  'BALRAMCHIN',
#  'PAGEIND',
#  'DECCANCE',
#  'KALPATPOWR',
#  'SAGCEM',
#  'LTI',
#  'BHARATRAS',
#  'NMDC']

# %%
gh(symbol=growth_stocks[i],start=start_date, end=(end_date))
# Out:
#            Symbol Series  Prev Close    Open    High     Low    Last   Close  \
# Date
# 2019-01-07   APCL     EQ      129.55  129.00  131.50  126.00  126.15  126.25
# 2019-01-08   APCL     EQ      126.25  125.90  127.00  125.90  126.35  126.85
# 2019-01-09   APCL     EQ      126.85  134.00  134.00  126.15  126.15  126.15
# 2019-01-10   APCL     EQ      126.15  129.35  132.30  129.35  129.75  129.80
# 2019-01-11   APCL     EQ      129.80  133.35  133.40  126.15  127.00  128.75
# ...           ...    ...         ...     ...     ...     ...     ...     ...
# 2019-05-09   APCL     EQ      128.40  129.90  138.45  126.55  131.25  134.35
# 2019-05-10   APCL     EQ      134.35  131.65  134.55  131.65  134.00  133.25
# 2019-05-13   APCL     EQ      133.25  132.00  132.00  123.00  131.00  123.90
# 2019-05-14   APCL     EQ      123.90  125.80  133.00  122.25  133.00  131.40
# 2019-05-15   APCL     EQ      131.40  128.90  145.90  127.25  139.00  142.95
#
# ...

# %%
data = gh(symbol=growth_stocks[i],start=start_date, end=(end_date))[['Symbol','Close']]

# %%
data.head()
# Out:
#            Symbol   Close
# Date
# 2019-01-07   APCL  126.25
# 2019-01-08   APCL  126.85
# 2019-01-09   APCL  126.15
# 2019-01-10   APCL  129.80
# 2019-01-11   APCL  128.75

# %%
data['Symbol'][0]
# Out:
# 'APCL'

# %%
    if i == 0: 
        df = data 
    if i != 0: 
        df = df.join(data)

# %%
df
# Out:
#            Symbol   Close
# Date
# 2019-01-07   APCL  126.25
# 2019-01-08   APCL  126.85
# 2019-01-09   APCL  126.15
# 2019-01-10   APCL  129.80
# 2019-01-11   APCL  128.75
# ...           ...     ...
# 2019-05-09   APCL  134.35
# 2019-05-10   APCL  133.25
# 2019-05-13   APCL  123.90
# 2019-05-14   APCL  131.40
# 2019-05-15   APCL  142.95
#
# [87 rows x 2 columns]

# %%
len(growth_stocks)
# Out:
# 9

# %%
data.head()
# Out:
#            Symbol   Close
# Date
# 2019-01-07   APCL  126.25
# 2019-01-08   APCL  126.85
# 2019-01-09   APCL  126.15
# 2019-01-10   APCL  129.80
# 2019-01-11   APCL  128.75

# %%
data.rename(columns={'Close':data['Symbol'][0]},inplace=True)

# %%
data['Symbol'][0]
# Out:
# 'APCL'

# %%
{'Close':data['Symbol'][0]}
# Out:
# {'Close': 'APCL'}

# %%
columns={'Close':data['Symbol'][0]}
columns
# Out:
# {'Close': 'APCL'}

# %%
data.rename(columns={'Close':data['Symbol'][0]},inplace=True)

# %%
data.head()
# Out:
#            Symbol    APCL
# Date
# 2019-01-07   APCL  126.25
# 2019-01-08   APCL  126.85
# 2019-01-09   APCL  126.15
# 2019-01-10   APCL  129.80
# 2019-01-11   APCL  128.75

# %%
data.drop(['Symbol'], axis=1,inplace=True)

# %%
data
# Out:
#               APCL
# Date
# 2019-01-07  126.25
# 2019-01-08  126.85
# 2019-01-09  126.15
# 2019-01-10  129.80
# 2019-01-11  128.75
# ...            ...
# 2019-05-09  134.35
# 2019-05-10  133.25
# 2019-05-13  123.90
# 2019-05-14  131.40
# 2019-05-15  142.95
#
# [87 rows x 1 columns]

# %%
for i in range(len(growth_stocks)):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8

# %%
for i in range(len(growth_stocks)): 
    data = gh(symbol=growth_stocks[i],start=start_date, end=(end_date))[['Symbol','Close']] 
    data.rename(columns={'Close':data['Symbol'][0]},inplace=True)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10140/2431389937.py in <module>
#       1 for i in range(len(growth_stocks)):
#       2     data = gh(symbol=growth_stocks[i],start=start_date, end=(end_date))[['Symbol','Close']]
# ----> 3     data.rename(columns={'Close':data['Symbol'][0]},inplace=True)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     937
#     938         if is_integer(key) and self.index._should_fallback_to_positional():
# --> 939             return self._values[key]
#     940
#     941         elif key_is_scalar:
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
len(data)
# Out:
# 0

# %%
if len(data) != 0:
    print(data)

# %%
for i in range(len(growth_stocks)): 
    data = gh(symbol=growth_stocks[i],start=start_date, end=(end_date))[['Symbol','Close']] 
    print(data.head())
    if len(data) != 0:
        data.rename(columns={'Close':data['Symbol'][0]},inplace=True) 
        data.drop(['Symbol'], axis=1,inplace=True) 
        if i == 0: 
            df = data
        if i != 0: 
            df = df.join(data)
# Out:
#            Symbol   Close
# Date
# 2019-01-07   APCL  126.25
# 2019-01-08   APCL  126.85
# 2019-01-09   APCL  126.15
# 2019-01-10   APCL  129.80
# 2019-01-11   APCL  128.75
#                 Symbol   Close
# Date
# 2019-01-07  BALRAMCHIN  108.00
# 2019-01-08  BALRAMCHIN  111.15
# 2019-01-09  BALRAMCHIN  108.80
# 2019-01-10  BALRAMCHIN  109.90
# 2019-01-11  BALRAMCHIN  111.10
#              Symbol     Close
# Date
# 2019-01-07  PAGEIND  21907.55
# 2019-01-08  PAGEIND  23021.60
# 2019-01-09  PAGEIND  23262.80
# 2019-01-10  PAGEIND  23176.35
# 2019-01-11  PAGEIND  23356.00
#               Symbol   Close
# Date
# 2019-01-07  DECCANCE  399.90
# 2019-01-08  DECCANCE  395.60
# 2019-01-09  DECCANCE  397.75
# 2019-01-10  DECCANCE  388.55
# 2019-01-11  DECCANCE  394.85
#                 Symbol   Close
# Date
# 2019-01-07  KALPATPOWR  377.85
# 2019-01-08  KALPATPOWR  383.20
# 2019-01-09  KALPATPOWR  382.80
# 2019-01-10  KALPATPOWR  380.40
# 2019-01-11  KALPATPOWR  380.80
# ...

# %%
df
# Out:
#               APCL  BALRAMCHIN   PAGEIND  DECCANCE  KALPATPOWR  SAGCEM  \
# Date
# 2019-01-07  126.25      108.00  21907.55    399.90      377.85  659.75
# 2019-01-08  126.85      111.15  23021.60    395.60      383.20  666.35
# 2019-01-09  126.15      108.80  23262.80    397.75      382.80  669.50
# 2019-01-10  129.80      109.90  23176.35    388.55      380.40  664.30
# 2019-01-11  128.75      111.10  23356.00    394.85      380.80  656.05
# ...            ...         ...       ...       ...         ...     ...
# 2019-05-09  134.35      144.60  21486.85    393.80      459.85  604.65
# 2019-05-10  133.25      144.60  21295.65    392.95      460.15  603.00
# 2019-05-13  123.90      136.25  21356.35    381.20      459.90  601.40
# 2019-05-14  131.40      141.60  21384.25    378.95      459.85  595.50
# 2019-05-15  142.95      141.05  21353.10    370.95      459.25  583.30
#
#             BHARATRAS   NMDC
# Date
# 2019-01-07    5199.95  94.95
# 2019-01-08    5163.85  94.95
# ...

# %%
start_date = date(2019, 1,7) 
end_date = date(2019,1, 11) 
df = pd.DataFrame() 

for i in range(len(growth_stocks)): 
    data = gh(symbol=growth_stocks[i],start=start_date, end=(end_date))[['Symbol','Close']] 
    print(data.head())
    if len(data) != 0:
        data.rename(columns={'Close':data['Symbol'][0]},inplace=True) 
        data.drop(['Symbol'], axis=1,inplace=True) 
        if i == 0: 
            df = data
        if i != 0: 
            df = df.join(data)
# Out:
#            Symbol   Close
# Date
# 2019-01-07   APCL  126.25
# 2019-01-08   APCL  126.85
# 2019-01-09   APCL  126.15
# 2019-01-10   APCL  129.80
# 2019-01-11   APCL  128.75
#                 Symbol   Close
# Date
# 2019-01-07  BALRAMCHIN  108.00
# 2019-01-08  BALRAMCHIN  111.15
# 2019-01-09  BALRAMCHIN  108.80
# 2019-01-10  BALRAMCHIN  109.90
# 2019-01-11  BALRAMCHIN  111.10
#              Symbol     Close
# Date
# 2019-01-07  PAGEIND  21907.55
# 2019-01-08  PAGEIND  23021.60
# 2019-01-09  PAGEIND  23262.80
# 2019-01-10  PAGEIND  23176.35
# 2019-01-11  PAGEIND  23356.00
#               Symbol   Close
# Date
# 2019-01-07  DECCANCE  399.90
# 2019-01-08  DECCANCE  395.60
# 2019-01-09  DECCANCE  397.75
# 2019-01-10  DECCANCE  388.55
# 2019-01-11  DECCANCE  394.85
#                 Symbol   Close
# Date
# 2019-01-07  KALPATPOWR  377.85
# 2019-01-08  KALPATPOWR  383.20
# 2019-01-09  KALPATPOWR  382.80
# 2019-01-10  KALPATPOWR  380.40
# 2019-01-11  KALPATPOWR  380.80
# ...

# %%
df
# Out:
#               APCL  BALRAMCHIN   PAGEIND  DECCANCE  KALPATPOWR  SAGCEM  \
# Date
# 2019-01-07  126.25      108.00  21907.55    399.90      377.85  659.75
# 2019-01-08  126.85      111.15  23021.60    395.60      383.20  666.35
# 2019-01-09  126.15      108.80  23262.80    397.75      382.80  669.50
# 2019-01-10  129.80      109.90  23176.35    388.55      380.40  664.30
# 2019-01-11  128.75      111.10  23356.00    394.85      380.80  656.05
#
#             BHARATRAS   NMDC
# Date
# 2019-01-07    5199.95  94.95
# 2019-01-08    5163.85  94.95
# 2019-01-09    5100.75  91.25
# 2019-01-10    5151.85  91.10
# 2019-01-11    5107.95  92.20

# %% [markdown]
# ### Stock Price History

# %%
from datetime import date
from nsepy import get_history
sbin = get_history(symbol='SBIN',
                   start=date(2015,1,1),
                   end=date(2015,1,10))
sbin
# Out:
#            Symbol Series  Prev Close    Open    High     Low    Last   Close  \
# Date
# 2015-01-01   SBIN     EQ      311.85  312.45  315.00  310.70  314.00  314.00
# 2015-01-02   SBIN     EQ      314.00  314.35  318.30  314.35  315.60  315.25
# 2015-01-05   SBIN     EQ      315.25  316.25  316.80  312.10  312.80  312.75
# 2015-01-06   SBIN     EQ      312.75  310.00  311.10  298.70  299.90  299.90
# 2015-01-07   SBIN     EQ      299.90  300.00  302.55  295.15  301.40  300.15
# 2015-01-08   SBIN     EQ      300.15  305.00  306.50  302.35  305.25  304.85
# 2015-01-09   SBIN     EQ      304.85  306.70  307.85  302.00  303.00  303.20
#
#               VWAP    Volume      Turnover  Trades  Deliverable Volume  \
# Date
# 2015-01-01  313.67   6138488  1.925489e+14   58688             1877677
# 2015-01-02  316.80   9935094  3.147389e+14   79553             4221685
# 2015-01-05  313.84   9136716  2.867432e+14   88236             3845173
# ...

# %% [markdown]
# <h2> Stock futures price history <h2>

# %%
from datetime import date
from nsepy import get_history
# Stock futures (Similarly for index futures, set index = True)
stock_fut = get_history(symbol="SBIN",
                        start=date(2015,1,1),
                        end=date(2015,1,10),
                        futures=True,
                        expiry_date=date(2015,1,29))
stock_fut
# Out:
#            Symbol      Expiry    Open    High     Low   Close    Last  \
# Date
# 2015-01-01   SBIN  2015-01-29  315.10  317.95  313.40  316.65  317.00
# 2015-01-02   SBIN  2015-01-29  317.50  320.95  317.10  317.75  318.30
# 2015-01-05   SBIN  2015-01-29  318.00  318.75  314.10  315.00  315.05
# 2015-01-06   SBIN  2015-01-29  312.95  312.95  300.10  301.30  301.10
# 2015-01-07   SBIN  2015-01-29  301.95  304.55  297.35  302.25  303.50
# 2015-01-08   SBIN  2015-01-29  306.50  308.40  303.70  306.65  307.00
# 2015-01-09   SBIN  2015-01-29  306.75  309.25  301.05  304.75  304.15
#
#             Settle Price  Number of Contracts      Turnover  Open Interest  \
# Date
# 2015-01-01        316.65                14720  5.821172e+09       55480000
# 2015-01-02        317.75                22525  8.988242e+09       55087500
# 2015-01-05        315.00                17455  6.898723e+09       55718750
# 2015-01-06        301.30                29338  1.126715e+10       56701250
# ...

# %%
### Stock options price history
- For stock options, specify-
- option_type as “CE” for call and as “PE” for put option
- strike_price - the strike price of the contract
- expiry_date - expiry date of the contract,

# %%
# Stock options (Similarly for index options, set index = True)
stock_opt = get_history(symbol="SBIN",
                        start=date(2015,1,1),
                        end=date(2015,1,10),
                        option_type="CE",
                        strike_price=300,
                        expiry_date=date(2015,1,29))
stock_opt
# Out:
#            Symbol      Expiry Option Type  Strike Price   Open   High    Low  \
# Date
# 2015-01-01   SBIN  2015-01-29          CE         300.0  18.95  21.15  18.95
# 2015-01-02   SBIN  2015-01-29          CE         300.0  21.50  23.90  21.35
# 2015-01-05   SBIN  2015-01-29          CE         300.0  21.00  21.00  18.60
# 2015-01-06   SBIN  2015-01-29          CE         300.0  16.10  16.80  10.50
# 2015-01-07   SBIN  2015-01-29          CE         300.0  11.05  12.50   9.00
# 2015-01-08   SBIN  2015-01-29          CE         300.0  13.50  13.85  11.90
# 2015-01-09   SBIN  2015-01-29          CE         300.0  13.70  14.20  10.50
#
#             Close   Last  Settle Price  Number of Contracts     Turnover  \
# Date
# 2015-01-01  20.85  20.95         20.85                   44   17631000.0
# 2015-01-02  21.45  21.40         21.45                   84   33889000.0
# 2015-01-05  18.60  18.60         18.60                   47   18775000.0
# ...

# %% [markdown]
# ### Index price history
# - There are currently 50+ indices maintained by NSE. You can get historical data for all of them.
#
# - Usage-
#     - symbol - Name of the index in capital (Refer this page for list of indices)
#     - index - Set this True for all index related operations

# %%
# NIFTY Next 50 index
nifty_next50 = get_history(symbol="NIFTY NEXT 50",
                            start=date(2015,1,1),
                            end=date(2015,1,10),
                            index=True)
# NIFTY50 Equal wight index (random index from the list)
nifty_eq_wt = get_history(symbol="NIFTY50 EQUAL WEIGHT",
                            start=date(2017,6,1),
                            end=date(2017,6,10),
                            index=True)

# %%
nifty_next50
# Out:
#                 Open      High       Low     Close    Volume      Turnover
# Date
# 2015-01-01  18655.65  18752.65  18638.00  18734.85  42634653  1.170750e+10
# 2015-01-02  18748.30  18964.30  18748.30  18883.15  65127256  2.364060e+10
# 2015-01-05  18902.40  19053.00  18822.35  18852.10  58256767  2.093900e+10
# 2015-01-06  18752.90  18752.90  18263.60  18312.35  81096398  2.764220e+10
# 2015-01-07  18323.40  18424.00  18133.70  18308.85  75084759  2.779550e+10
# 2015-01-08  18488.15  18690.55  18476.45  18662.10  78886563  2.689510e+10
# 2015-01-09  18789.50  18828.60  18494.10  18633.95  79723949  2.792390e+10

# %%
nifty_eq_wt
# Out:
#             Open  High  Low     Close     Volume      Turnover
# Date
# 2017-06-01   NaN   NaN  NaN  11789.64  181533283  9.482610e+10
# 2017-06-02   NaN   NaN  NaN  11839.64  167195027  8.564300e+10
# 2017-06-05   NaN   NaN  NaN  11873.78  131685021  7.192240e+10
# 2017-06-06   NaN   NaN  NaN  11804.67  150379695  8.416550e+10
# 2017-06-07   NaN   NaN  NaN  11846.42  165669924  8.989360e+10
# 2017-06-08   NaN   NaN  NaN  11825.27  160165459  8.822630e+10
# 2017-06-09   NaN   NaN  NaN  11840.46  163897548  9.078710e+10

# %% [markdown]
# You will observe a lot of NaN values for many indeces like ‘NIFTY50 Equal wight index’, In those cases just use ‘Close’ values

# %% [markdown]
# ### Index futures price history
# - Out of the 60+ indices, only 7 indeces are available for derivative. (List available here.) Usage-
# - index - Set True
# - futures - Set True
# - expiry_date - Expiry date of the contract

# %%
nifty_fut = get_history(symbol="NIFTY",
                        start=date(2015,1,1),
                        end=date(2015,1,10),
                        index=True,
                        futures=True,
                        expiry_date=date(2015,1,29))
nifty_fut
# Out:
#            Symbol      Expiry     Open    High      Low    Close     Last  \
# Date
# 2015-01-01  NIFTY  2015-01-29  8320.00  8356.0  8295.20  8343.80  8347.05
# 2015-01-02  NIFTY  2015-01-29  8352.25  8470.9  8352.25  8458.40  8468.00
# 2015-01-05  NIFTY  2015-01-29  8452.35  8492.0  8406.00  8422.85  8423.85
# 2015-01-06  NIFTY  2015-01-29  8422.00  8422.0  8000.00  8157.90  8150.30
# 2015-01-07  NIFTY  2015-01-29  8150.00  8184.0  8096.00  8141.85  8154.00
# 2015-01-08  NIFTY  2015-01-29  8209.00  8274.9  8193.10  8257.25  8255.00
# 2015-01-09  NIFTY  2015-01-29  8306.35  8334.0  8205.00  8315.50  8311.60
#
#             Settle Price  Number of Contracts      Turnover  Open Interest  \
# Date
# 2015-01-01       8343.80               152053  3.165350e+10       21140550
# 2015-01-02       8458.40               384440  8.105711e+10       21427925
# 2015-01-05       8422.85               362889  7.661895e+10       20698500
# ...

# %% [markdown]
# ### Index options price history
# - Usage-
# - index - Set True
# - option_type as “CE” for call and as “PE” for put option
# - strike_price - the strike price of the contract
# - expiry_date - expiry date of the contract

# %%
nifty_opt = get_history(symbol="NIFTY",
                        start=date(2015,1,1),
                        end=date(2015,1,10),
                        index=True,
                        option_type='CE',
                        strike_price=8200,
                        expiry_date=date(2015,1,29))
nifty_opt
# Out:
#            Symbol      Expiry Option Type  Strike Price    Open    High  \
# Date
# 2015-01-01  NIFTY  2015-01-29          CE        8200.0  170.10  223.00
# 2015-01-02  NIFTY  2015-01-29          CE        8200.0  224.25  301.50
# 2015-01-05  NIFTY  2015-01-29          CE        8200.0  285.50  313.85
# 2015-01-06  NIFTY  2015-01-29          CE        8200.0  207.05  207.05
# 2015-01-07  NIFTY  2015-01-29          CE        8200.0  115.05  125.80
# 2015-01-08  NIFTY  2015-01-29          CE        8200.0  130.00  155.80
# 2015-01-09  NIFTY  2015-01-29          CE        8200.0  170.15  185.70
#
#                Low   Close    Last  Settle Price  Number of Contracts  \
# Date
# 2015-01-01  170.10  214.85  217.50        214.85                25091
# 2015-01-02  219.55  287.20  298.00        287.20                35187
# 2015-01-05  245.20  257.85  255.50        257.85                16551
# 2015-01-06  102.80  110.00  107.90        110.00               280463
# ...

# %% [markdown]
# ### India VIX price history
# India VIX is a volatility index which gives a measurement of market volatility based on NIFTY options contract.
# This servers as important parameter in option pricing.

# %%
vix = get_history(symbol="INDIAVIX",
            start=date(2015,1,1),
            end=date(2015,1,10),
            index=True)
vix
# Out:
#                Open     High      Low    Close  Previous  Change  %Change
# Date
#                 NaN      NaN      NaN      NaN       NaN     NaN      NaN
# 2015-01-01  15.1200  15.5075  14.7550  15.0250   15.1200   -0.10  -0.0063
# 2015-01-02  15.0250  15.0250  13.4825  13.7950   15.0250   -1.23  -0.0819
# 2015-01-05  13.7950  14.4050  13.1525  14.1525   13.7950    0.36   0.0259
# 2015-01-06  14.1525  17.8700  13.4575  17.4200   14.1525    3.27   0.2309
# 2015-01-07  17.4200  19.0700  16.5025  18.1400   17.4200    0.72   0.0413
# 2015-01-08  18.1400  18.1400  15.3825  16.4725   18.1400   -1.67  -0.0919
# 2015-01-09  16.4725  16.9075  14.4625  15.9550   16.4725   -0.52  -0.0314
