# %% [markdown]
# ### Close Price and Adjusted Close price
#
#    #### 1- Close Price
#
#    Close Price of a Stock refers to the last price of a stock with in perticular time frame.
#
#    #### 2 - Adjusted Close Price -
#    the adjusted closing price considers other factors like dividends, stock splits, and new stock offerings.
#                 Since the adjusted closing price begins where the closing price ends,
#                 it can be called a more accurate measure of stocks value.
#
#   #### 3 - Stock Split -
#    A stock split is when the number of shares gets multiplied. There is a ‘split’ in the number of shares held.
#    Technically no new shares are being issued by the company. The existing number of shares are being divided
#    or split. Say a company announces a stock split in the 1:2 ratio. It means for every 1 share held, it will
#    become 2 shares, for every 100 shares held, the share count will become 200 shares.

# %% [markdown]
# #### Example
# - Stock Split
#
# Stock split ratio: 1:2
#
#     - Before stock split
#         Share count: 100 shares
#         Stock price: Rs 100
#         Face Value: Rs 10
#
#     - After stock split
#         Share count: 200 shares
#         Stock price: (Rs100*100shares)/200 shares Rs 50
#         Face Value: Rs 5
#
# Face value is the value of stocks listed in its books and share certificate. It remains fixed and is decided at the time of issuance unless there is a stock split. In a stock split, since the same shares are being split in a certain ratio, the face value also gets split in the same ratio.

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

data = pd.read_csv("data/AAPL.csv")

#Print top 5 Rows
data.head()
# Out:
#          Date    Open    High     Low     Close      Volume  Ex-Dividend  \
# 0  2007-12-03  181.86  184.14  177.70  178.8600  34338200.0          0.0
# 1  2007-12-04  177.15  180.90  176.99  179.8100  27635700.0          0.0
# 2  2007-12-05  182.89  186.00  182.41  185.5000  31871500.0          0.0
# 3  2007-12-06  186.19  190.10  186.12  189.9528  32136100.0          0.0
# 4  2007-12-07  190.54  194.99  188.04  194.3000  38073800.0          0.0
#
#    Split Ratio  Adj. Open  Adj. High   Adj. Low  Adj. Close  Adj. Volume
# 0          1.0  23.371545  23.664556  22.836927   22.986003  240367400.0
# 1          1.0  22.766244  23.248171  22.745682   23.108091  193449900.0
# 2          1.0  23.503914  23.903592  23.442227   23.839335  223100500.0
# 3          1.0  23.928010  24.430500  23.919014   24.411582  224952700.0
# 4          1.0  24.487046  25.058933  24.165761   24.970258  266516600.0

# %%
#Print bottom 5 Rows
data.tail()
# Out:
#             Date    Open    High     Low   Close      Volume  Ex-Dividend  \
# 2512  2017-11-27  175.05  175.08  173.34  174.09  20536313.0          0.0
# 2513  2017-11-28  174.30  174.87  171.86  173.07  25468442.0          0.0
# 2514  2017-11-29  172.63  172.92  167.16  169.48  40788324.0          0.0
# 2515  2017-11-30  170.43  172.14  168.44  171.85  40172368.0          0.0
# 2516  2017-12-01  169.95  171.67  168.50  171.05  39590080.0          0.0
#
#       Split Ratio  Adj. Open  Adj. High  Adj. Low  Adj. Close  Adj. Volume
# 2512          1.0     175.05     175.08    173.34      174.09   20536313.0
# 2513          1.0     174.30     174.87    171.86      173.07   25468442.0
# 2514          1.0     172.63     172.92    167.16      169.48   40788324.0
# 2515          1.0     170.43     172.14    168.44      171.85   40172368.0
# 2516          1.0     169.95     171.67    168.50      171.05   39590080.0

# %%
#Plot Graph using closing price
data["Close"].plot()
# Out:
# <AxesSubplot:>

# %%
#Plot Graph using Adj. closing price
data["Adj. Close"].plot()
# plt.plot(data.Date,data.AdjClose)
plt.title("Close Price Vs Adj. Close Price")
plt.show()

# %% [markdown]
# #### So from the above chart we can we we have a sharp fall in the stock prices at 600 point and this is the place where stock split took part.
