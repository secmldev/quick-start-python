# %%
from mod_my_utils.read_write_data import get_price_csv
from mod_my_utils.misc import summary
from mod_my_utils.plot_stock import plot_stock
from mod_my_utils.misc import stocks_dataframe
from mod_my_utils.misc import stocks_summary

# %%
stocks_names = ['AAPL','MSFT', 'IBM', 'ADBE']
folder_name = 'data/'
index = 'Date'

# %%
stocks_names
# Out:
# ['AAPL', 'MSFT', 'IBM', 'ADBE']

# %% [markdown]
# ### For loop for multiple stocks

# %%
for stock in stocks_names:
#     print('stock name ', stock)
    data = get_price_csv(folder_name, stock, index)
    summary(data)
    plot_stock(stock,data, ['Open'])
# Out:
# stock name:  AAPL
# Columns of data frame
#  Index(['Open', 'High', 'Low', 'Close', 'Volume', 'Ex-Dividend', 'Split Ratio',
#        'Adj. Open', 'Adj. High', 'Adj. Low', 'Adj. Close', 'Adj. Volume'],
#       dtype='object')
# Row information
#  DatetimeIndex(['2007-12-03', '2007-12-04', '2007-12-05', '2007-12-06',
#                '2007-12-07', '2007-12-10', '2007-12-11', '2007-12-12',
#                '2007-12-13', '2007-12-14',
#                ...
#                '2017-11-17', '2017-11-20', '2017-11-21', '2017-11-22',
#                '2017-11-24', '2017-11-27', '2017-11-28', '2017-11-29',
#                '2017-11-30', '2017-12-01'],
#               dtype='datetime64[ns]', name='Date', length=2517, freq=None)
# First few rows
#                Open    High     Low   Close      Volume  Ex-Dividend  \
# Date
# 2007-12-03  181.86  184.14  177.70  178.86  34338200.0          0.0
# 2007-12-04  177.15  180.90  176.99  179.81  27635700.0          0.0
# ...

# %%
data.head()
# Out:
#              Open   High    Low  Close     Volume  Ex-Dividend  Split Ratio  \
# Date
# 2007-12-03  41.87  43.10  41.85  42.69  9153400.0          0.0          1.0
# 2007-12-04  42.22  43.65  42.22  43.32  6540200.0          0.0          1.0
# 2007-12-05  43.93  44.29  43.61  43.90  5883900.0          0.0          1.0
# 2007-12-06  44.20  44.64  43.71  44.54  5545300.0          0.0          1.0
# 2007-12-07  44.30  44.54  43.87  44.37  3709400.0          0.0          1.0
#
#             Adj. Open  Adj. High  Adj. Low  Adj. Close  Adj. Volume
# Date
# 2007-12-03      41.87      43.10     41.85       42.69    9153400.0
# 2007-12-04      42.22      43.65     42.22       43.32    6540200.0
# 2007-12-05      43.93      44.29     43.61       43.90    5883900.0
# 2007-12-06      44.20      44.64     43.71       44.54    5545300.0
# 2007-12-07      44.30      44.54     43.87       44.37    3709400.0

# %% [markdown]
# ### Multiple stocks adjusted closing price

# %%
stocks_names = ['AAPL','MSFT', 'IBM', 'ADBE']
folder_path = 'data/'

# %%
stocks_names
# Out:
# ['AAPL', 'MSFT', 'IBM', 'ADBE']

# %% [markdown]
# ### Assumption
# - All the stocks data is available for same date range
# - What if for few stocks data not available for few dates

# %%
help(stocks_dataframe)
# Out:
# Help on function stocks_dataframe in module mod_my_utils.misc:
#
# stocks_dataframe(stocks_names, start_date, end_date, data_source)
#     Input: stocks_names is a list of stock, start date, end date, data source
#     Output: Data frame with date as index, different columns has different adjusted closing price

# %%
stocks_dataframe(folder_path, stocks_names)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20300/588403732.py in <module>
# ----> 1 stocks_dataframe(folder_path, stocks_names)
#
# TypeError: stocks_dataframe() missing 2 required positional arguments: 'end_date' and 'data_source'

# %% [markdown]
# ### Mutliple stocks summary

# %%
stocks_summary(folder_path, stocks_names)
# Out:
# Folder name =  data/
# stock Name =  AAPL
# Folder name =  data/
# stock Name =  MSFT
# Folder name =  data/
# stock Name =  IBM
# Folder name =  data/
# stock Name =  ADBE
# Stocks Name:  Index(['AAPL', 'MSFT', 'IBM', 'ADBE'], dtype='object')
# Dates:  DatetimeIndex(['2007-12-03', '2007-12-04', '2007-12-05', '2007-12-06',
#                '2007-12-07', '2007-12-10', '2007-12-11', '2007-12-12',
#                '2007-12-13', '2007-12-14',
#                ...
#                '2017-11-17', '2017-11-20', '2017-11-21', '2017-11-22',
#                '2017-11-24', '2017-11-27', '2017-11-28', '2017-11-29',
#                '2017-11-30', '2017-12-01'],
#               dtype='datetime64[ns]', name='Date', length=2517, freq=None)
# Summary of stocks price:
#                AAPL         MSFT          IBM         ADBE
# count  2517.000000  2517.000000  2517.000000  2517.000000
# mean     69.521432    34.078189   135.882034    58.346441
# ...
