# %% [markdown]
# ### String

# %%
str1 = "hello python"

# %%
str1
# Out:
# 'Anant'

# %%
str1 = 'Anant'

# %% [markdown]
# ### OOP

# %%
## truck1
### values, variables
- no of wheels
- load
- capacity
- color
- model no
- seats
- fueltype
- engine power
- mileage
### action, methods
- run
- stop
- reverse
- break
- left trun
- right turn
- unload

# %%
- Everything is object in python

# %%
str1 = 'anant'

# %%
str1.count('a')
# Out:
# 2

# %%
str1.count('n')
# Out:
# 2

# %%
str1.capitalize()
# Out:
# 'Anant'

# %%
len(str1)
# Out:
# 5

# %%
str1.index('t')
# Out:
# 4

# %%
anant

01234

# %%
a = 3
b = 2
a + b
a - b
a * b
# Out:
# 6

# %%
a = 'jay'
b = 'hello'
a + b
# a - b
a * b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-a2a89f2f095d> in <module>
#       3 a + b
#       4 # a - b
# ----> 5 a * b
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
10 * a
# Out:
# 'jayjayjayjayjayjayjayjayjayjay'

# %%
def addition(a, b):
    return a + b

# %%
addition(2, 3)
# Out:
# 5

# %%
addition('hello', 'prakhar')
# Out:
# 'helloprakhar'

# %%
- Manusha
- OOP example
- truck
- another example
- use jupyter notebook
- 5 minutes
