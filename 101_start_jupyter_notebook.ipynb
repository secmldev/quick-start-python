# %% [markdown]
# ### Start jupyter notebook
# - start menu, select jupyter notebook
# - conda command prompt, $ jupyter notebook

# %% [markdown]
# # Operating jupyter notebook shortcuts
# - esc + b for adding a new cell below the current cell
# - esc + a for adding a new cell above the current cell
# - esc + m to get the cell in markdown mode
# - esc + d + d to delete a current cell
# - ![title1](path of file) to add a image to the current cell
# - shift + enter to run the current cell and move to next cell
# - ctrl + enter to run the current cell

# %%
a = 3
a
# Out:
# 3

# %%
a = 3
a
b = 3
c = 4
print(c)
print(b)
# Out:
# 4
# 3

# %% [markdown]
# # ![](img/macd1.png)

# %% [markdown]
# ![](img/macd1.png)

# %% [markdown]
# ![](img/macd1.png)

# %%
b + c
# Out:
# 7

# %%
d = 2

# %%
d
# Out:
# 2

# %%
a = *
# Out:
#   File "<ipython-input-19-fd2094608b7a>", line 1
#     a = *
#          ^
# SyntaxError: invalid syntax

# %%
a = 69

# %%
a =

# %%
3
# Out:
# 3

# %%
'python'
# Out:
# 'python'

# %%
True
# Out:
# True

# %%
3.5
# Out:
# 3.5

# %%
6 / 3
# Out:
# 2.0

# %%
a = '    hello python'
a
# Out:
# '    hello python'

# %% [markdown]
# - method
# - function

# %% [markdown]
# ### Method

# %%
a = 3
b = 2

# %%
c = a + b
c
# Out:
# 5

# %%
def addition(a, d, b = 10):
    c = a + b
    return c

# %%
addition(3, 4)
# Out:
# 13

# %%
addition(5, 7)
# Out:
# 12

# %%
addition(a=2, b=5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-df32efcda49f> in <module>
# ----> 1 addition(d=2, b=5)
#
# TypeError: addition() got an unexpected keyword argument 'd'

# %%
- import pandas
- method
- collection
    - list
    - tuple
    - dict
    - set
- Nitish recording
    - upto collection
- explore string in python
- read stock data file aapl.csv

# %%
print
# Out:
# <function print>

# %% [markdown]
# ### How to code in python

# %%
print("Hello python")
# Out:
# Hello python

# %%
print("what is your name")
# Out:
# what is your name

# %%
c
# Out:
# 5

# %%
a = 5

# %%
print(a)
# Out:
# 5

# %%
print(a + a)
# Out:
# 10

# %% [markdown]
# - i am python

# %%
print(a)
print(b)
print(addition(2, 12))
# Out:
# 5
# 2
# 12

# %%
a
b

# %% [markdown]
# - i am python
