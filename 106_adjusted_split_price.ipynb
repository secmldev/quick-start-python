# %% [markdown]
# ## What Is a Split-Adjusted Share Price?
#
# If a company has undergone stock splits over its lifetime comparing historical stock prices to those of the present day doesn't accurately reflect performance.
#
# ### Explanation
# When a company issues a stock split, it increases the number of outstanding shares available. Doing so doesn't only increase the number of shares, it also affects the share price—hence the term split adjustment share price. When the price is adjusted because of a stock split, it is reduced by a certain fraction. So, a two-for-one stock split takes an existing share and splits it into two, adjusting the price by half. Similarly, a three-for-one stock split takes one share and splits it into three new shares. The price for this split is adjusted—or divided—by three.
#
# ### Calculation
# To calculate the number of new shares you will have after a stock split, multiply the number of shares you currently own by the number of new shares being issued for each existing share. For example, say a company that you own 150 shares of is doing a 2-for-1 stock split. Multiply 150 by 2 to find that after the stock split, you’ll own 300 new shares
#
#
# #### Example- Apple Computer, Inc.
# Below is an example of split adjusted share price for Apple Computer, Inc., which is an American multinational technology company that specializes in consumer electronics, computer software, and online services.
#
# A 7-for-1 stock split happed for Apple (stock symbol-AAPL on June 9, 2014. Below is a graphical comparison of Apple's unadjusted and adjusted share price.
#
# <img src="Apple-news.JPG" style ="width:600px;"/>
#
# [Reference 1](https://www.investopedia.com/ask/answers/04/031104.asp)
# [Reference 2](https://budgeting.thenest.com/calculate-stock-splits-10078.html)
# [Reference 3](https://investor.apple.com/faq/default.aspx)

# %%
import pandas as pd
import os
import numpy as np

# %%
AAPL = pd.read_csv("data/AAPL.csv")

# %%
AAPL.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Ex-Dividend',
#        'Split Ratio', 'Adj. Open', 'Adj. High', 'Adj. Low', 'Adj. Close',
#        'Adj. Volume'],
#       dtype='object')

# %%
AAPL['Date']= pd.to_datetime(AAPL['Date'])

# %%
AAPL.dtypes
# Out:
# Date           datetime64[ns]
# Open                  float64
# High                  float64
# Low                   float64
# Close                 float64
# Volume                float64
# Ex-Dividend           float64
# Split Ratio           float64
# Adj. Open             float64
# Adj. High             float64
# Adj. Low              float64
# Adj. Close            float64
# Adj. Volume           float64
# dtype: object

# %%
AAPL1 = pd.read_csv("data/AAPL.csv", index_col='Date')

# %%
AAPL1.head()
# Out:
#               Open    High     Low     Close      Volume  Ex-Dividend  \
# Date
# 2007-12-03  181.86  184.14  177.70  178.8600  34338200.0          0.0
# 2007-12-04  177.15  180.90  176.99  179.8100  27635700.0          0.0
# 2007-12-05  182.89  186.00  182.41  185.5000  31871500.0          0.0
# 2007-12-06  186.19  190.10  186.12  189.9528  32136100.0          0.0
# 2007-12-07  190.54  194.99  188.04  194.3000  38073800.0          0.0
#
#             Split Ratio  Adj. Open  Adj. High   Adj. Low  Adj. Close  \
# Date
# 2007-12-03          1.0  23.371545  23.664556  22.836927   22.986003
# 2007-12-04          1.0  22.766244  23.248171  22.745682   23.108091
# 2007-12-05          1.0  23.503914  23.903592  23.442227   23.839335
# 2007-12-06          1.0  23.928010  24.430500  23.919014   24.411582
# 2007-12-07          1.0  24.487046  25.058933  24.165761   24.970258
#
#             Adj. Volume
# Date
# 2007-12-03  240367400.0
# 2007-12-04  193449900.0
# 2007-12-05  223100500.0
# ...

# %%
Price_Plot = AAPL1[['Close', 'Adj. Close','Split Ratio']].plot(title='Figure 1 - Unadjusted/Adjusted Closing Price Comparison',figsize=(15,5),xlabel="Dates", ylabel="Close Price",rot=45)

# %%
Volume_Plot = AAPL1[['Volume','Adj. Volume']].plot(title='Figure 2 - Unadjusted/Adjusted Volume Comparison',figsize=(15,5),xlabel="Dates", ylabel="Volume",rot=45)

# %% [markdown]
# As we can see from Figure 1, the split happend on June 9, 2014 prior to which the close proce was 645.57, post 7-1 split the adjusted price came down to 88.2, which would give false impression that market went extremely bearish on that day, but if we look at the adjusted close price line , we can observe the stock price is follwoing the same trend range as pre-split close price. In order to prevent these kinds of misleading signals from appearing on our charts, we adjust all the historical data prior to the event.
#
#
# **_Other Observations:_**
#
# - We can see a similar change in Volumes Figure 2 where there is corresponding increase in the volume due to stock split
#
# - Similar to adjustment due to stock split, the data contains micro adjustsment made at various dates for Ex Dividend. Multiple ex Dividend adjustments were made at the following dates
#
# Date | Ex-Dividend
# -----|-----
# 2017-08-10  |  0.63
# 2017-05-11  |  0.63
# 2017-02-09  |  0.57
# 2016-11-03  |  0.57
# 2016-08-04  |  0.57
# 2016-05-05  |  0.57
# 2016-02-04  |  0.52
# 2015-11-05  |  0.52
# 2015-08-06  |  0.52
# 2015-05-07  |  0.52
# 2015-02-05  |  0.47
# 2014-11-06  |  0.47
# 2014-08-07  |  0.47
# 2014-05-08  |  3.29
# 2014-02-06  |  3.05
# 2013-11-06  |  3.05
# 2013-08-08  |  3.05
# 2013-05-09  |  3.05
# 2013-02-07  |  2.65
# 2012-11-07  |  2.65
# 2012-08-09  |  2.65
#
# Since the adjustment due Ex dividend are very minor in comparison to the stock split, these adjustments are not clearly visible in the plot.
#
# **Conclusion: For discerning and analyzing the real performance of the stock, it is standard to adjust the old prices to reflect the splits and Ex Dividends**
