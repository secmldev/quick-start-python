# %% [markdown]
# ### Learning pandas
# 1. create pandas data frame
# 2. pandas series

# %% [markdown]
# - pandas - panel data
# - panel
# - data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
i = ['a', 'b', 'c']

# %%
i
# Out:
# ['a', 'b', 'c']

# %%
type(i)
# Out:
# list

# %%
pd
# Out:
# <module 'pandas' from 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\pandas\\__init__.py'>

# %%
type(pd)
# Out:
# module

# %%
type(np)
# Out:
# module

# %%
print(np)
# Out:
# <module 'numpy' from 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\numpy\\__init__.py'>

# %%
d = [10,20,30]
d
# Out:
# [10, 20, 30]

# %%
type(d)
# Out:
# list

# %%
list1 = ['Athula', 'Rohan', 50, [10, 20]]

# %%
type(list1)
# Out:
# list

# %%
i
# Out:
# ['a', 'b', 'c']

# %%
pd.Series(i)
# Out:
# 0    a
# 1    b
# 2    c
# dtype: object

# %%
temp1 = pd.Series(i)

# %%
type(temp1)
# Out:
# pandas.core.series.Series

# %%
help(pd)
# Out:
# Help on package pandas:
#
# NAME
#     pandas
#
# DESCRIPTION
#     pandas - a powerful data analysis and manipulation library for Python
# ...
#
#     **pandas** is a Python package providing fast, flexible, and expressive data
#     structures designed to make working with "relational" or "labeled" data both
#     easy and intuitive. It aims to be the fundamental high-level building block for
#     doing practical, **real world** data analysis in Python. Additionally, it has
#     the broader goal of becoming **the most powerful and flexible open source data
#     analysis / manipulation tool available in any language**. It is already well on
#     its way toward this goal.
#
#     Main Features
#     -------------
#     Here are just a few of the things that pandas does well:
#
#       - Easy handling of missing data in floating point as well as non-floating
#         point data.
#       - Size mutability: columns can be inserted and deleted from DataFrame and
# ...

# %%
help(pd.Series)
# Out:
# Help on class Series in module pandas.core.series:
#
# class Series(pandas.core.base.IndexOpsMixin, pandas.core.generic.NDFrame)
#  |  Series(data=None, index=None, dtype: 'Dtype | None' = None, name=None, copy: 'bool' = False, fastpath: 'bool' = False)
#  |
#  |  One-dimensional ndarray with axis labels (including time series).
#  |
#  |  Labels need not be unique but must be a hashable type. The object
#  |  supports both integer- and label-based indexing and provides a host of
#  |  methods for performing operations involving the index. Statistical
#  |  methods from ndarray have been overridden to automatically exclude
#  |  missing data (currently represented as NaN).
#  |
#  |  Operations between Series (+, -, /, *, **) align values based on their
#  |  associated index values-- they need not be the same length. The result
#  |  index will be the sorted union of the two indexes.
#  |
#  |  Parameters
#  |  ----------
#  |  data : array-like, Iterable, dict, or scalar value
# ...

# %%
d
# Out:
# [10, 20, 30]

# %%
s1 = pd.Series(data=d, index= i)
s1
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
s1
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
s1['a']
# Out:
# 10

# %%
s1.sum()
# Out:
# 60

# %%
s1.prod()
# Out:
# 6000

# %%
help(pd.DataFrame)
# Out:
# Help on class DataFrame in module pandas.core.frame:
#
# class DataFrame(pandas.core.generic.NDFrame, pandas.core.arraylike.OpsMixin)
#  |  DataFrame(data=None, index: 'Axes | None' = None, columns: 'Axes | None' = None, dtype: 'Dtype | None' = None, copy: 'bool | None' = None)
#  |
#  |  Two-dimensional, size-mutable, potentially heterogeneous tabular data.
#  |
#  |  Data structure also contains labeled axes (rows and columns).
#  |  Arithmetic operations align on both row and column labels. Can be
#  |  thought of as a dict-like container for Series objects. The primary
#  |  pandas data structure.
#  |
#  |  Parameters
#  |  ----------
#  |  data : ndarray (structured or homogeneous), Iterable, dict, or DataFrame
#  |      Dict can contain Series, arrays, constants, dataclass or list-like objects. If
#  |      data is a dict, column order follows insertion-order.
#  |
#  |      .. versionchanged:: 0.25.0
# ...

# %% [markdown]
# # Data Frames

# %%
df= pd.DataFrame(np.random.rand(3,5), index= ['A','B','C'], columns=['price','Volume', 'Return Rate','Open', 'Close'])
df
# Out:
#       price    Volume  Return Rate      Open     Close
# A  0.243128  0.330738     0.370354  0.654556  0.370568
# B  0.571407  0.797777     0.936724  0.695159  0.271211
# C  0.199407  0.892266     0.173698  0.370562  0.479249

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
np.random.rand(3, 5)
# Out:
# array([[0.72249477, 0.23725204, 0.40493702, 0.9713287 , 0.40519613],
#        [0.82722613, 0.84166764, 0.12187719, 0.85320315, 0.87876144],
#        [0.70349732, 0.31984523, 0.99263027, 0.16281491, 0.35665739]])

# %%
help(pd.DataFrame)
# Out:
# Help on class DataFrame in module pandas.core.frame:
#
# class DataFrame(pandas.core.generic.NDFrame, pandas.core.arraylike.OpsMixin)
#  |  DataFrame(data=None, index: 'Axes | None' = None, columns: 'Axes | None' = None, dtype: 'Dtype | None' = None, copy: 'bool | None' = None)
#  |
#  |  Two-dimensional, size-mutable, potentially heterogeneous tabular data.
#  |
#  |  Data structure also contains labeled axes (rows and columns).
#  |  Arithmetic operations align on both row and column labels. Can be
#  |  thought of as a dict-like container for Series objects. The primary
#  |  pandas data structure.
#  |
#  |  Parameters
#  |  ----------
#  |  data : ndarray (structured or homogeneous), Iterable, dict, or DataFrame
#  |      Dict can contain Series, arrays, constants, dataclass or list-like objects. If
#  |      data is a dict, column order follows insertion-order.
#  |
#  |      .. versionchanged:: 0.25.0
# ...

# %%
df
# Out:
#       price    Volume  Return Rate      Open     Close
# A  0.243128  0.330738     0.370354  0.654556  0.370568
# B  0.571407  0.797777     0.936724  0.695159  0.271211
# C  0.199407  0.892266     0.173698  0.370562  0.479249

# %%
df[['price', 'Close']]
# Out:
#       price     Close
# A  0.243128  0.370568
# B  0.571407  0.271211
# C  0.199407  0.479249

# %%
type(df['price'])
# Out:
# pandas.core.series.Series

# %%
df.loc[['A', 'B']]
# Out:
#       price    Volume  Return Rate      Open     Close
# A  0.243128  0.330738     0.370354  0.654556  0.370568
# B  0.571407  0.797777     0.936724  0.695159  0.271211

# %%
df['Volume']['A']
# Out:
# 0.3307380873700333

# %%
df.loc['C'].loc['Volume']
# Out:
# 0.8922657304060274

# %%
out = ['LEB', 'LEB', 'LEB', 'FR', 'FR', 'FR', 'USA', 'USA', 'USA']
inside = ['A', 'B', 'c', 'A', 'B', 'c', 'A', 'B', 'c']
indexRows=zip(out, inside)
indexRows = pd.MultiIndex.from_tuples(indexRows)
df1 = pd.DataFrame(np.random.rand(9,3), indexRows, ['price', 'Close', 'Open'])
df1
# Out:
#           price     Close      Open
# LEB A  0.647789  0.841804  0.720077
#     B  0.834782  0.386848  0.282499
#     c  0.122120  0.494941  0.728197
# FR  A  0.653313  0.421587  0.570384
#     B  0.662210  0.078428  0.394108
#     c  0.950167  0.980329  0.557267
# USA A  0.964121  0.530239  0.435637
#     B  0.823019  0.250496  0.835538
#     c  0.897632  0.533011  0.064502

# %%
list(zip('abcdefg', range(3), range(4)))
# Out:
# [('a', 0, 0), ('b', 1, 1), ('c', 2, 2)]

# %% [markdown]
# # Grouping Elements (Aggregate Functions)

# %%
dict ={'Country': ['Leb','Leb', 'FR','FR', 'UY','UY','Nig','Nig'], 'Stock Price': [31,321,13,12,59,130,320,90]}
df2 = pd.DataFrame(dict,['a','b','c','d','e','f','g','h'] )
df2
# Out:
#   Country  Stock Price
# a     Leb           31
# b     Leb          321
# c      FR           13
# d      FR           12
# e      UY           59
# f      UY          130
# g     Nig          320
# h     Nig           90

# %%
df2.describe().loc['min']
# Out:
# Stock Price    12.0
# Name: min, dtype: float64

# %%
df2.groupby('Country').describe().T
# Out:
# Country                   FR         Leb        Nig          UY
# Stock Price count   2.000000    2.000000    2.00000    2.000000
#             mean   12.500000  176.000000  205.00000   94.500000
#             std     0.707107  205.060967  162.63456   50.204581
#             min    12.000000   31.000000   90.00000   59.000000
#             25%    12.250000  103.500000  147.50000   76.750000
#             50%    12.500000  176.000000  205.00000   94.500000
#             75%    12.750000  248.500000  262.50000  112.250000
#             max    13.000000  321.000000  320.00000  130.000000

# %%
df2.groupby('Country').std()
# Out:
#          Stock Price
# Country
# FR          0.707107
# Leb       205.060967
# Nig       162.634560
# UY         50.204581

# %% [markdown]
# ### Read CSV

# %%
#load the data
df3= pd.read_csv("data/AAPL.csv")

# %%
df3
# Out:
#             Date    Open    High     Low     Close      Volume  Ex-Dividend  \
# 0     2007-12-03  181.86  184.14  177.70  178.8600  34338200.0          0.0
# 1     2007-12-04  177.15  180.90  176.99  179.8100  27635700.0          0.0
# 2     2007-12-05  182.89  186.00  182.41  185.5000  31871500.0          0.0
# 3     2007-12-06  186.19  190.10  186.12  189.9528  32136100.0          0.0
# 4     2007-12-07  190.54  194.99  188.04  194.3000  38073800.0          0.0
# ...          ...     ...     ...     ...       ...         ...          ...
# 2512  2017-11-27  175.05  175.08  173.34  174.0900  20536313.0          0.0
# 2513  2017-11-28  174.30  174.87  171.86  173.0700  25468442.0          0.0
# 2514  2017-11-29  172.63  172.92  167.16  169.4800  40788324.0          0.0
# 2515  2017-11-30  170.43  172.14  168.44  171.8500  40172368.0          0.0
# 2516  2017-12-01  169.95  171.67  168.50  171.0500  39590080.0          0.0
#
# ...

# %%
df3= df3.set_index(pd.DatetimeIndex(df3['Date'].values))

# %%
df3
# Out:
#                   Date    Open    High     Low     Close      Volume  \
# 2007-12-03  2007-12-03  181.86  184.14  177.70  178.8600  34338200.0
# 2007-12-04  2007-12-04  177.15  180.90  176.99  179.8100  27635700.0
# 2007-12-05  2007-12-05  182.89  186.00  182.41  185.5000  31871500.0
# 2007-12-06  2007-12-06  186.19  190.10  186.12  189.9528  32136100.0
# 2007-12-07  2007-12-07  190.54  194.99  188.04  194.3000  38073800.0
# ...                ...     ...     ...     ...       ...         ...
# 2017-11-27  2017-11-27  175.05  175.08  173.34  174.0900  20536313.0
# 2017-11-28  2017-11-28  174.30  174.87  171.86  173.0700  25468442.0
# 2017-11-29  2017-11-29  172.63  172.92  167.16  169.4800  40788324.0
# 2017-11-30  2017-11-30  170.43  172.14  168.44  171.8500  40172368.0
# 2017-12-01  2017-12-01  169.95  171.67  168.50  171.0500  39590080.0
#
#             Ex-Dividend  Split Ratio   Adj. Open   Adj. High    Adj. Low  \
# ...

# %%
plt.figure(figsize=(20.2,4.5))
plt.plot(df3['Close'], label='Close')
plt.title('Close Price history')
plt.xlabel('Date')
plt.xticks(rotation=45)
plt.ylabel('Price USD $')
plt.show()

# %%
df3.plot(x='Date', y='Close')
# Out:
# <AxesSubplot:xlabel='Date'>
